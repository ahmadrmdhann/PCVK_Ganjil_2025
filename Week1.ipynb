# %% [markdown]
# <a href="https://colab.research.google.com/github/ahmadrmdhann/PCVK_Ganjil_2025/blob/main/Week1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Langkah 1
#
# Pada code awal, beberapa library yang akan digunakan adalah: numpy, pandas, cv2, skimage, PIL, matplotlib

# %%
import numpy as np
import pandas as pd
import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io
from skimage import transform
from PIL import Image
import matplotlib.pylab as plt

# %% [markdown]
# ## Langkah 2
#
# Baca image dari URLs

# %%
urls = ["https://iiif.lib.ncsu.edu/iiif/0052574/full/800,/0/default.jpg",
        "https://iiif.lib.ncsu.edu/iiif/0016007/full/800,/0/default.jpg",
        "https://avatars.githubusercontent.com/u/72720340?v=4"]

for url in urls:
    image = io.imread(url)
    image = cv.resize(image, (0,0), fx=0.5, fy=0.5)
    image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
    final_frame = cv.hconcat([image, image_2])
    cv2_imshow(final_frame)
    print('\n')
# Out:
# <PIL.Image.Image image mode=RGB size=800x276>
# <PIL.Image.Image image mode=RGB size=800x286>
# <PIL.Image.Image image mode=RGB size=460x230>

# %% [markdown]
# ## Langkah 3
# Melihat ukuran file image

# %%
tinggi = image_2.shape[0]
lebar = image_2.shape[1]
print("Resolusi image: tinggi x lebar = ", tinggi, "x", lebar)
cv2_imshow(image_2)
# Out:
# Resolusi image: tinggi x lebar =  230 x 230
# <PIL.Image.Image image mode=RGB size=230x230>

# %% [markdown]
# ## Langkah 4
#
# mengakses pixel dengan memberi garis diagonal melintang

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

for y in range(lebar):
    image_3[int((tinggi)/2), y] = [255, 255, 255]

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=460x230>

# %% [markdown]
# ## Pertanyaan
# 1. Jelaskan, mengapa pada modul praktikum ini eksekusi kode Python dilakukan menggunakan Google Colab?
# 2. Jelaskan mengenai kegunaan setiap library pada praktikum langkah ke delapan? Apakah semua library tersebut harus digunakan dalam praktikum sesi ini?
# 3. Pada uji coba langkah ke-9 terdapat potongan kode program sebagai berikut :
#
# ![WhatsApp Image 2025-09-09 at 11.32.32.jpeg](data:image/jpeg;base64,...)
#
# Apa kegunaan kode program tersebut?dan apa pengaruhnya jika tidak dilakukan?
#
# 4. Perhatikan potongan kode progam berikut :
#
# ![WhatsApp Image 2025-09-09 at 11.25.52.jpeg](data:image/jpeg;base64,...)
#
# Apakah kegunaan kode [255,255,255] ? Jelaskan!
#
# 5. Jelaskan keterkaitan antara pixel dan juga resolusi gambar yang tinggi ataupun
# rendah!

# %% [markdown]
# ## Jawaban
#
# 1. Keunggulan dari Google Collab dibandingkan menggunakan IDE, antara lain:
#
# * Gratis dan mudah diakses
# * Library sudah terinstall
# * Tidak memerlukan untuk melakukan setup environment python
# * Dapat connect ke Github dan Drive secara bersamaan
#
# 2. Library yang dipakai pada praktikum diatas adalah:
#   * NumPy & Pandas: Diimpor tapi tidak secara langsung digunakan dalam kode yang ditampilkan.
#   * OpenCV (cv2): Digunakan untuk memproses gambar (baca, ubah warna, ubah ukuran, gabung gambar).
#   * cv2_imshow: Digunakan khusus di Colab untuk menampilkan gambar OpenCV.
#   * Skimage (io): Digunakan untuk membaca gambar dari URL.
#   * Skimage (transform) & PIL & Matplotlib: Diimpor tapi tidak secara langsung digunakan dalam kode yang ditampilkan.
#
# 3. Potongan kode tersebut digunakan untuk resize ukuran gambar sehingga ukuran gambar tidak terlalu besar
#
# 4. Kode [255, 255, 255] digunakan untuk memberikan warna putih pada garis horizontal yang dibuat
#
# 5. Semakin tinggi resolusi gambar, semakin banyak pixel yang dimilikinya, dan semakin baik kualitas serta detail gambar tersebut. Sebaliknya, semakin rendah resolusi gambar, semakin sedikit pixelnya, dan kualitas gambar akan menurun, terutama saat diperbesar.

# %% [markdown]
# ## Tugas Praktikum
#
# 1. Buat garis vertikal dan garis menyilang diagonal pada image keluaran

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

for x in range(tinggi):
    image_3[x, int(lebar/2)] = [255, 255, 255]

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=460x230>

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

for i in range(min(tinggi, lebar)):
    image_3[i, i] = [255, 255, 255]

for i in range(min(tinggi, lebar)):
    image_3[i, lebar - 1 - i] = [255, 255, 255]

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=460x230>

# %% [markdown]
# 2. Buat garis horisontal berwarna putih dibagian tengah gambar dengan panjang tertentu

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

panjang_garis = lebar // 2
start_x = (lebar - panjang_garis) // 2
end_x = start_x + panjang_garis
y_tengah = int(tinggi / 2)

for x in range(start_x, end_x):
    image_3[y_tengah, x] = [255, 255, 255]

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=460x230>

# %% [markdown]
# 3. Buat kotak menggunakan kumpulan pixel warna putih di sembarang tempat dalam gambar

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

x_awal = 65
y_awal = 40
kotak_lebar = 100
kotak_tinggi = 80

for y in range(y_awal, y_awal + kotak_tinggi):
    for x in range(x_awal, x_awal + kotak_lebar):
        image_3[y, x] = [255, 255, 255]

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=460x230>
